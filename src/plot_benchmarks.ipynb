# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tmp_v100 = [
0.027013778686523438, 
0.020045042037963867,       
0.017920970916748047,     
0.017277002334594727,       
0.018546342849731445,       
0.016864538192749023,       
0.023108243942260742,       
0.019199609756469727,       
0.027196884155273438,       
0.03685927391052246,        
0.031075477600097656,       
0.04776144027709961,        
0.041466712951660156,       
0.0335848331451416,         
0.039594173431396484,       
0.035470008850097656,       
0.029693126678466797      
]

tmp_hpc_head = [
0.026543140411376953
,0.018032550811767578
,0.015653133392333984
,0.014698266983032227
,0.01787281036376953
,0.01930999755859375
,0.021409273147583008
,0.035147905349731445
,0.03143143653869629
,0.02511000633239746
,0.02298283576965332
,0.0255734920501709
,0.04489541053771973
,0.025551319122314453
,0.07640719413757324
,0.03258156776428223
,0.0261075496673584
]

tmp_hpc_compute = [
0.03293299674987793                                                     
,0.015070676803588867                                                    
,0.015978097915649414                                                    
,0.016504287719726562                                                    
,0.017392635345458984                                                    
,0.015529632568359375                                                    
,0.01591181755065918                                                     
,0.016640663146972656                                                    
,0.016850948333740234                                                    
,0.0310666561126709                                                      
,0.018709659576416016                                                    
,0.038108110427856445                                                    
,0.028026342391967773                                                    
,0.033889055252075195                                                    
,0.08278489112854004                                                     
,0.0358278751373291                                                      
,0.03769993782043457                                                     
]

# %%
x_axis = list(range(1, 82, 5))
plt.plot(x_axis, tmp_v100, label='v100')
plt.plot(x_axis, tmp_hpc_head, label='hpc_head')
plt.plot(x_axis, tmp_hpc_compute, label='hpc_compute')
plt.legend()

# %%
tmp_hpc = [
0.51358270645
,0.13856077194
,0.16959738731
,0.14385271072
,0.20822954177
,0.24390792846
,0.28672552108
,0.32066702842
,0.67474508285
,2.17724394798
,2.29383206367
,2.30684328079
,2.32019472122
,2.78268933296
,2.96084833145
,3.11071157455
,3.30280447006
]

x_axis = list(range(1, 82, 5))
plt.plot(x_axis, tmp_hpc, label='hpc')
plt.xlabel('intra-op threads')
plt.ylabel('time')
plt.savefig('./bench80.jpg')

# %%
# RNN con num thread da 1 a 21
tmp_hpc = [
0.517541
,0.325164
,0.252745
,0.215286
,0.180427
,0.158829
,0.168936
,0.131282
,0.161739
,0.163923
,0.171262
,0.155869
,0.150534
,0.156214
,0.151907
,0.145771
,0.170761
,0.183705
,0.220488
,0.193699
,0.223199
]
x_axis = list(range(1, 22, 1))
plt.plot(x_axis, tmp_hpc, label='hpc')
plt.xlabel('intra-op threads')
plt.ylabel('time')
plt.savefig('./bench20.jpg')
